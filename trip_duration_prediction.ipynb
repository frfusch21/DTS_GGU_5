# %% [markdown]
# <a href="https://colab.research.google.com/github/frfusch21/DTS_GGU_5/blob/Hartantya-AT/trip_duration_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from sklearn import preprocessing

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

from sklearn.cluster import KMeans

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Import Data**

# %%
uio = pd.read_csv('/content/drive/MyDrive/Belajar/bog_clean.csv', header=0, sep=',', encoding="Latin1")
uio.head()
# Out:
#    id vendor_id      pickup_datetime     dropoff_datetime  pickup_longitude  \
# 0   1   BogotÃ¡  2016-09-18 01:54:11  2016-09-18 02:17:49        -74.170353
# 1   2   BogotÃ¡  2016-09-18 03:31:05  2016-09-18 03:44:06        -74.123542
# 2   3   BogotÃ¡  2016-08-07 03:35:36  2016-09-18 04:30:31        -74.178643
# 3   4   BogotÃ¡  2016-09-18 04:31:13  2016-09-18 04:32:19        -74.163398
# 4   5   BogotÃ¡  2016-09-13 12:07:04  2016-09-18 05:00:44        -74.137539
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude store_and_fwd_flag  \
# 0         4.622699         -74.119259          4.572322                  N
# 1         4.604075         -74.116125          4.572578                  N
# 2         4.646176         -74.178711          4.646367                  N
# 3         4.641949         -74.165813          4.640649                  N
# 4         4.596347         -74.125364          4.576745                  N
#
#    trip_duration  dist_meters  wait_sec
# 0           1419        11935       293
# 1            782         7101       139
# 2        3632095         2655      2534
# 3             66          318        52
# 4         449620         3228       211

# %%
uio.describe()
# Out:
#                 id  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  3063.000000       3063.000000      3063.000000        3063.000000
# mean   1532.000000        -74.098884         4.670920         -74.100136
# std     884.356263          0.138975         0.091885           0.139508
# min       1.000000        -76.534419         3.391712         -76.542536
# 25%     766.500000        -74.123948         4.629166         -74.122538
# 50%    1532.000000        -74.085985         4.683676         -74.089411
# 75%    2297.500000        -74.055464         4.717402         -74.058683
# max    3063.000000        -73.829723         5.029401         -73.615700
#
#        dropoff_latitude  trip_duration   dist_meters      wait_sec
# count       3063.000000   3.063000e+03  3.063000e+03  3.063000e+03
# mean           4.669038   9.295603e+04 -1.392301e+06  9.652921e+05
# std            0.092942   5.899404e+05  5.486590e+07  3.757377e+07
# min            3.391941   2.000000e+00 -2.147484e+09  0.000000e+00
# 25%            4.625974   5.385000e+02  1.672000e+03  9.100000e+01
# 50%            4.677560   1.442000e+03  5.375000e+03  3.000000e+02
# 75%            4.719314   3.813000e+03  1.085600e+04  8.445000e+02
# max            5.029189   1.227617e+07  3.478510e+05  1.471920e+09

# %%
uio.shape
# Out:
# (3063, 12)

# %% [markdown]
# # **Analisis Secara Umum**

# %%
print(uio['vendor_id'].unique())
print(uio['store_and_fwd_flag'].unique())
# Out:
# ['BogotÃ¡' 'BogotÃ¡ UberX' 'Bogota UberBlack' 'BogotÃ¡ UberVan'
#  'BogotÃ¡ UberAngel']
# ['N']

# %%
print(uio.groupby(['vendor_id'])['id'].count().reset_index())
# Out:
#            vendor_id    id
# 0   Bogota UberBlack   244
# 1            BogotÃ¡  2537
# 2  BogotÃ¡ UberAngel    11
# 3    BogotÃ¡ UberVan    54
# 4      BogotÃ¡ UberX   217

# %%
x = uio.groupby(['vendor_id'])['id'].count()
sns.barplot(x.index, x.values)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
uio.isnull().values.any()
# Out:
# False

# %%
uio =  uio.loc[uio['vendor_id']=='BogotÃ¡']

# %%
correlation_matrix = uio.corr()
correlation_matrix
# Out:
#                          id  pickup_longitude  pickup_latitude  \
# id                 1.000000          0.001876         0.049489
# pickup_longitude   0.001876          1.000000         0.562691
# pickup_latitude    0.049489          0.562691         1.000000
# dropoff_longitude -0.000680          0.641561         0.421037
# dropoff_latitude   0.056549          0.409979         0.707961
# trip_duration      0.024598         -0.072542         0.003453
# dist_meters       -0.021393          0.016071         0.026968
# wait_sec           0.022904         -0.011065        -0.008690
#
#                    dropoff_longitude  dropoff_latitude  trip_duration  \
# id                         -0.000680          0.056549       0.024598
# pickup_longitude            0.641561          0.409979      -0.072542
# pickup_latitude             0.421037          0.707961       0.003453
# dropoff_longitude           1.000000          0.466282      -0.056963
# dropoff_latitude            0.466282          1.000000      -0.009344
# trip_duration              -0.056963         -0.009344       1.000000
# dist_meters                 0.007385          0.010231       0.004492
# wait_sec                   -0.010016         -0.007082      -0.004085
#
#                    dist_meters  wait_sec
# id                   -0.021393  0.022904
# pickup_longitude      0.016071 -0.011065
# pickup_latitude       0.026968 -0.008690
# dropoff_longitude     0.007385 -0.010016
# dropoff_latitude      0.010231 -0.007082
# trip_duration         0.004492 -0.004085
# dist_meters           1.000000  0.000788
# wait_sec              0.000788  1.000000

# %% [markdown]
# # **Analisis Data Trip Duration**

# %%
sns.set()
uio['log_trip_duration'] = np.log(uio['trip_duration'].values + 1)
plt.hist(uio['log_trip_duration'].values, bins=100)
plt.xlabel('log(trip_duration)')
plt.ylabel('number of train records')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x = uio.groupby(['vendor_id'])['log_trip_duration'].mean()
sns.barplot(x.index, x.values)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print((uio['trip_duration'].min())/3600)
print((uio['trip_duration'].max())/3600)
# Out:
# 0.0005555555555555556
# 3410.0461111111113

# %%
uio['trip_duration_in_minutes'] =  uio['trip_duration']/60

# %%
uio = uio[(uio['trip_duration_in_minutes'] >= 0.05)]
uio.shape
# Out:
# (2536, 14)

# %%
print((uio['trip_duration_in_minutes'].min()))
print((uio['trip_duration_in_minutes'].max()))
# Out:
# 0.05
# 204602.76666666666

# %%
z_scores = stats.zscore(uio[['trip_duration_in_minutes']])
z_scores

# Convert to absolute values
abs_z_scores = np.abs(z_scores)

# Select data points with a z-scores above or below 3
filtered_entries = (abs_z_scores < 3).all(axis=1)
# Filter the dataset
uio = uio[filtered_entries]
uio.shape
# Out:
# (2501, 14)

# %%
print((uio['trip_duration_in_minutes'].min()))
print((uio['trip_duration_in_minutes'].max()))
# Out:
# 0.05
# 29993.65

# %%
# calculate Q1 and Q3
Q1 = uio[['trip_duration_in_minutes']].quantile(0.25)
Q3 = uio[['trip_duration_in_minutes']].quantile(0.75)

# calculate the IQR
IQR = Q3 - Q1

# filter the dataset with the IQR
IQR_outliers =  uio[['trip_duration_in_minutes']][(( uio[['trip_duration_in_minutes']] < (Q1 - 1.5 * IQR)) |( uio[['trip_duration_in_minutes']] > (Q3 + 1.5 * IQR))).any(axis=1)]
min_outlier = IQR_outliers.min()
print(min_outlier)
# Out:
# trip_duration_in_minutes    121.1
# dtype: float64

# %%
uio = uio[(uio['trip_duration_in_minutes'] < 121.1)]
uio.shape
# Out:
# (2170, 14)

# %% [markdown]
# # **Analisis Data Datetime**

# %%
uio['pickup_datetime'] = pd.to_datetime(uio['pickup_datetime'], format='%Y/%m/%d %H:%M:%S')
uio['dropoff_datetime'] = pd.to_datetime(uio['dropoff_datetime'], format='%Y-%m-%d %H:%M:%S')

# %%
print('Pickup -> Date : max = ', uio['pickup_datetime'].dt.date.max(), ' & min = ',uio['pickup_datetime'].dt.date.min(), ' || Time : Max = ', uio['pickup_datetime'].dt.time.max(), ' & min = ', uio['pickup_datetime'].dt.time.min())

print('Dropoff -> Date : max = ', uio['dropoff_datetime'].dt.date.max(), ' & min = ',uio['dropoff_datetime'].dt.date.min(), ' || Time : Max = ', uio['dropoff_datetime'].dt.time.max(), ' & min = ', uio['dropoff_datetime'].dt.time.min())
# Out:
# Pickup -> Date : max =  2017-07-20  & min =  2016-06-23  || Time : Max =  12:59:57  & min =  01:00:01
# Dropoff -> Date : max =  2017-07-20  & min =  2016-06-23  || Time : Max =  12:59:22  & min =  01:00:50

# %%
uio['diff_datetime_minutes'] = (uio['dropoff_datetime']-uio['pickup_datetime']).dt.total_seconds()/60

# %%
uio[(uio['trip_duration_in_minutes'] != uio['diff_datetime_minutes'])]
# Out:
#         id vendor_id     pickup_datetime    dropoff_datetime  \
# 0        1   BogotÃ¡ 2016-09-18 01:54:11 2016-09-18 02:17:49
# 1        2   BogotÃ¡ 2016-09-18 03:31:05 2016-09-18 03:44:06
# 5        6   BogotÃ¡ 2016-09-18 05:39:06 2016-09-18 06:37:07
# 6        7   BogotÃ¡ 2016-09-18 07:33:15 2016-09-18 08:07:08
# 8        9   BogotÃ¡ 2016-09-18 10:11:54 2016-09-18 10:17:01
# ...    ...       ...                 ...                 ...
# 3053  3054   BogotÃ¡ 2016-10-27 04:13:14 2016-10-27 04:15:33
# 3054  3055   BogotÃ¡ 2016-10-27 04:16:10 2016-10-27 04:42:08
# 3055  3056   BogotÃ¡ 2016-10-27 06:37:55 2016-10-27 07:50:48
# 3056  3057   BogotÃ¡ 2016-10-27 09:00:36 2016-10-27 09:52:21
# 3060  3061   BogotÃ¡ 2016-10-27 12:28:22 2016-10-27 01:16:58
#
#       pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0           -74.170353         4.622699         -74.119259          4.572322
# 1           -74.123542         4.604075         -74.116125          4.572578
# 5           -74.026595         4.761352         -74.086588          4.578945
# 6           -74.155331         4.599743         -74.038229          4.764599
# 8           -74.049272         4.718333         -74.030313          4.710932
# ...                ...              ...                ...               ...
# 3053        -74.161670         4.591986         -74.157820          4.581066
# 3054        -74.156281         4.578133         -74.157015          4.565806
# 3055        -74.154898         4.637313         -74.048568          4.684500
# 3056        -74.072112         4.631299         -74.042742          4.701864
# 3060        -74.061556         4.709213         -74.042396          4.708566
#
#      store_and_fwd_flag  trip_duration  dist_meters  wait_sec  \
# 0                     N           1419        11935       293
# 1                     N            782         7101       139
# 5                     N           3482        27760       796
# 6                     N           2034        27136       215
# 8                     N            308         2358        93
# ...                 ...            ...          ...       ...
# 3053                  N            140         1313        18
# 3054                  N           1559         3940      1039
# 3055                  N           4374        14743      1193
# 3056                  N           3106        11368       780
# 3060                  N           2917        10994      1401
#
#       log_trip_duration  trip_duration_in_minutes  diff_datetime_minutes
# 0              7.258412                 23.650000              23.633333
# 1              6.663133                 13.033333              13.016667
# 5              8.155649                 58.033333              58.016667
# 6              7.618251                 33.900000              33.883333
# 8              5.733341                  5.133333               5.116667
# ...                 ...                       ...                    ...
# 3053           4.948760                  2.333333               2.316667
# 3054           7.352441                 25.983333              25.966667
# 3055           8.383662                 72.900000              72.883333
# 3056           8.041413                 51.766667              51.750000
# 3060           7.978654                 48.616667            -671.400000
#
# [1235 rows x 15 columns]

# %%
uio = uio[(uio['diff_datetime_minutes'] >= 0)]
uio.shape
# Out:
# (2105, 15)

# %% [markdown]
# # **Data Trip Duration VS Datetime**

# %%
uio['pickup_month'] = uio['pickup_datetime'].dt.month
uio['pickup_year'] = uio['pickup_datetime'].dt.year
uio['pickup_day'] = uio['pickup_datetime'].dt.day
uio['pickup_hour'] = uio['pickup_datetime'].dt.hour
uio['pickup_minute'] = uio['pickup_datetime'].dt.minute
uio['pickup_day_of_week'] = uio['pickup_datetime'].dt.dayofweek
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
f, axes = plt.subplots(3,2,figsize=(17,10), sharey=True)

dat = uio.groupby(['pickup_hour'])['id'].count()
fig1 = sns.barplot(dat.index, dat.values, ax=axes[0,0])
#fig1.set_ylim = 3000

dat = uio.groupby(['pickup_hour'])['trip_duration'].mean()
fig2 = sns.barplot(dat.index, dat.values, ax=axes[0,1])
#fig2.set_ylim = 3000

dat = uio.groupby(['pickup_day_of_week'])['id'].count()
fig1 = sns.barplot(dat.index, dat.values, ax=axes[1,0])
#fig1.set_ylim = 3000

dat = uio.groupby(['pickup_day_of_week'])['trip_duration'].mean()
fig2 = sns.barplot(dat.index, dat.values, ax=axes[1,1])

dat = uio.groupby(['pickup_month'])['id'].count()
fig1 = sns.barplot(dat.index, dat.values, ax=axes[2,0])
#fig1.set_ylim = 3000

dat = uio.groupby(['pickup_month'])['trip_duration'].mean()
fig2 = sns.barplot(dat.index, dat.values, ax=axes[2,1])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Analisis Data Distance Meters**

# %%
sns.set()
uio['log_dist_meters'] = np.log(uio['dist_meters'].values + 1)
plt.hist(uio['log_dist_meters'].values, bins=100)
plt.xlabel('log(dist_meters)')
plt.ylabel('number of train records')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %%
x = uio.groupby(['vendor_id'])['dist_meters'].mean()
sns.barplot(x.index, x.values)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print((uio['dist_meters'].min())/1000)
print((uio['dist_meters'].max())/1000)
# Out:
# -2147483.648
# 60.853

# %%
uio['dist_kilometers'] =  uio['dist_meters']/1000

# %%
z_scores = stats.zscore(uio[['dist_kilometers']])
z_scores

# Convert to absolute values
abs_z_scores = np.abs(z_scores)

# Select data points with a z-scores above or below 3
filtered_entries = (abs_z_scores < 3).all(axis=1)

# Filter the dataset
uio = uio[filtered_entries]
uio.shape
# Out:
# (2103, 23)

# %%
print((uio['dist_kilometers'].min()))
print((uio['dist_kilometers'].max()))
# Out:
# 0.011
# 60.853

# %%
# calculate Q1 and Q3
Q1 = uio[['dist_kilometers']].quantile(0.25)
Q3 = uio[['dist_kilometers']].quantile(0.75)

# calculate the IQR
IQR = Q3 - Q1

# filter the dataset with the IQR
IQR_outliers =  uio[['dist_kilometers']][(( uio[['dist_kilometers']] < (Q1 - 1.5 * IQR)) |( uio[['dist_kilometers']] > (Q3 + 1.5 * IQR))).any(axis=1)]
min_outlier = IQR_outliers.min()
print(min_outlier)
# Out:
# dist_kilometers    20.231
# dtype: float64

# %%
uio = uio[(uio['dist_kilometers'] < 20.231)]
uio.shape
# Out:
# (2011, 23)

# %% [markdown]
# # **Clustering**

# %%
num_clusters = 2

# %% [markdown]
# Pickup

# %%
K_clusters = range(1,10)
kmeans = [KMeans(n_clusters=i) for i in K_clusters]
Y_axis = uio[['pickup_latitude']]
X_axis = uio[['pickup_longitude']]
score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]
# Visualize
plt.plot(K_clusters, score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
kmeans = KMeans(n_clusters = num_clusters, init ='k-means++', max_iter=100, n_init=1, verbose=0, random_state=3425)
kmeans.fit(uio[['pickup_latitude', 'pickup_longitude']]) # Compute k-means clustering.
uio['cluster_pickup'] = kmeans.fit_predict(uio[['pickup_latitude', 'pickup_longitude']])
centers = kmeans.cluster_centers_ # Coordinates of cluster centers.
labels = kmeans.predict(uio[['pickup_latitude', 'pickup_longitude']]) # Labels of each point
uio.head(10)
# Out:
#     id vendor_id     pickup_datetime    dropoff_datetime  pickup_longitude  \
# 0    1   BogotÃ¡ 2016-09-18 01:54:11 2016-09-18 02:17:49        -74.170353
# 1    2   BogotÃ¡ 2016-09-18 03:31:05 2016-09-18 03:44:06        -74.123542
# 3    4   BogotÃ¡ 2016-09-18 04:31:13 2016-09-18 04:32:19        -74.163398
# 7    8   BogotÃ¡ 2016-09-18 10:08:31 2016-09-18 10:11:42        -74.049168
# 8    9   BogotÃ¡ 2016-09-18 10:11:54 2016-09-18 10:17:01        -74.049272
# 9   10   BogotÃ¡ 2016-09-19 06:38:17 2016-09-19 06:56:23        -74.129042
# 11  12   BogotÃ¡ 2016-09-19 12:16:52 2016-09-19 12:44:15        -74.107296
# 13  14   BogotÃ¡ 2016-09-19 01:39:38 2016-09-19 01:54:46        -74.050705
# 14  15   BogotÃ¡ 2016-09-19 02:05:05 2016-09-19 02:05:48        -74.076370
# 15  16   BogotÃ¡ 2016-09-19 02:06:00 2016-09-19 02:16:14        -74.077873
#
#     pickup_latitude  dropoff_longitude  dropoff_latitude store_and_fwd_flag  \
# 0          4.622699         -74.119259          4.572322                  N
# 1          4.604075         -74.116125          4.572578                  N
# 3          4.641949         -74.165813          4.640649                  N
# 7          4.736697         -74.050641          4.718745                  N
# 8          4.718333         -74.030313          4.710932                  N
# 9          4.656129         -74.164118          4.623704                  N
# 11         4.654408         -74.102383          4.615875                  N
# 13         4.752136         -74.050896          4.752045                  N
# 14         4.606665         -74.077545          4.607023                  N
# 15         4.607366         -74.091487          4.604315                  N
#
#     trip_duration  ...  pickup_year  pickup_day  pickup_hour  pickup_minute  \
# 0            1419  ...         2016          18            1             54
# 1             782  ...         2016          18            3             31
# 3              66  ...         2016          18            4             31
# 7             191  ...         2016          18           10              8
# 8             308  ...         2016          18           10             11
# 9            1086  ...         2016          19            6             38
# 11           1643  ...         2016          19           12             16
# 13            909  ...         2016          19            1             39
# 14             43  ...         2016          19            2              5
# 15            615  ...         2016          19            2              6
#
#     pickup_day_of_week  log_dist_meters  dist_kilometers  cluster_pickup_ref3  \
# 0                    6         9.387314           11.935                    0
# 1                    6         8.868132            7.101                    0
# 3                    6         5.765191            0.318                    0
# 7                    6         7.807510            2.458                    1
# 8                    6         7.765993            2.358                    1
# 9                    0         8.678802            5.876                    0
# 11                   0         8.878776            7.177                    0
# 13                   0         8.934719            7.590                    1
# 14                   0         5.198497            0.180                    0
# 15                   0         7.701652            2.211                    0
#
#     cluster_pickup  cluster_dropoff
# 0                0                2
# 1                2                2
# 3                0                2
# 7                1                1
# 8                1                1
# 9                0                2
# 11               3                2
# 13               1                1
# 14               2                2
# 15               2                2
#
# [10 rows x 26 columns]

# %%
uio.plot.scatter(x = 'pickup_latitude', y = 'pickup_longitude', c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
x = uio.groupby(['cluster_pickup'])['id'].count()
sns.barplot(x.index, x.values)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x = uio.groupby(['cluster_pickup'])['trip_duration_in_minutes'].mean()
sns.barplot(x.index, x.values)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Dropoff

# %%
K_clusters = range(1,10)
kmeans = [KMeans(n_clusters=i) for i in K_clusters]
Y_axis = uio[['dropoff_latitude']]
X_axis = uio[['dropoff_longitude']]
score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]
# Visualize
plt.plot(K_clusters, score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
kmeans = KMeans(n_clusters = num_clusters, init ='k-means++', max_iter=100, n_init=1, verbose=0, random_state=3425)
kmeans.fit(uio[['dropoff_latitude', 'dropoff_longitude']]) # Compute k-means clustering.
uio['cluster_dropoff'] = kmeans.fit_predict(uio[['dropoff_latitude', 'dropoff_longitude']])
centers = kmeans.cluster_centers_ # Coordinates of cluster centers.
labels = kmeans.predict(uio[['dropoff_latitude', 'dropoff_longitude']]) # Labels of each point
uio.head(10)
# Out:
#     id vendor_id     pickup_datetime    dropoff_datetime  pickup_longitude  \
# 0    1   BogotÃ¡ 2016-09-18 01:54:11 2016-09-18 02:17:49        -74.170353
# 1    2   BogotÃ¡ 2016-09-18 03:31:05 2016-09-18 03:44:06        -74.123542
# 3    4   BogotÃ¡ 2016-09-18 04:31:13 2016-09-18 04:32:19        -74.163398
# 7    8   BogotÃ¡ 2016-09-18 10:08:31 2016-09-18 10:11:42        -74.049168
# 8    9   BogotÃ¡ 2016-09-18 10:11:54 2016-09-18 10:17:01        -74.049272
# 9   10   BogotÃ¡ 2016-09-19 06:38:17 2016-09-19 06:56:23        -74.129042
# 11  12   BogotÃ¡ 2016-09-19 12:16:52 2016-09-19 12:44:15        -74.107296
# 13  14   BogotÃ¡ 2016-09-19 01:39:38 2016-09-19 01:54:46        -74.050705
# 14  15   BogotÃ¡ 2016-09-19 02:05:05 2016-09-19 02:05:48        -74.076370
# 15  16   BogotÃ¡ 2016-09-19 02:06:00 2016-09-19 02:16:14        -74.077873
#
#     pickup_latitude  dropoff_longitude  dropoff_latitude store_and_fwd_flag  \
# 0          4.622699         -74.119259          4.572322                  N
# 1          4.604075         -74.116125          4.572578                  N
# 3          4.641949         -74.165813          4.640649                  N
# 7          4.736697         -74.050641          4.718745                  N
# 8          4.718333         -74.030313          4.710932                  N
# 9          4.656129         -74.164118          4.623704                  N
# 11         4.654408         -74.102383          4.615875                  N
# 13         4.752136         -74.050896          4.752045                  N
# 14         4.606665         -74.077545          4.607023                  N
# 15         4.607366         -74.091487          4.604315                  N
#
#     trip_duration  ...  pickup_year  pickup_day  pickup_hour  pickup_minute  \
# 0            1419  ...         2016          18            1             54
# 1             782  ...         2016          18            3             31
# 3              66  ...         2016          18            4             31
# 7             191  ...         2016          18           10              8
# 8             308  ...         2016          18           10             11
# 9            1086  ...         2016          19            6             38
# 11           1643  ...         2016          19           12             16
# 13            909  ...         2016          19            1             39
# 14             43  ...         2016          19            2              5
# 15            615  ...         2016          19            2              6
#
#     pickup_day_of_week  log_dist_meters  dist_kilometers  cluster_pickup_ref3  \
# 0                    6         9.387314           11.935                    0
# 1                    6         8.868132            7.101                    0
# 3                    6         5.765191            0.318                    0
# 7                    6         7.807510            2.458                    1
# 8                    6         7.765993            2.358                    1
# 9                    0         8.678802            5.876                    0
# 11                   0         8.878776            7.177                    0
# 13                   0         8.934719            7.590                    1
# 14                   0         5.198497            0.180                    0
# 15                   0         7.701652            2.211                    0
#
#     cluster_pickup  cluster_dropoff
# 0                0                2
# 1                2                2
# 3                0                2
# 7                1                1
# 8                1                1
# 9                0                2
# 11               3                2
# 13               1                1
# 14               2                0
# 15               2                0
#
# [10 rows x 26 columns]

# %%
uio.plot.scatter(x = 'dropoff_latitude', y = 'dropoff_longitude', c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
x = uio.groupby(['cluster_dropoff'])['id'].count()
sns.barplot(x.index, x.values)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x = uio.groupby(['cluster_dropoff'])['trip_duration_in_minutes'].mean()
sns.barplot(x.index, x.values)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Cek Korelasi**

# %%
uio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2011 entries, 0 to 3061
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        2011 non-null   int64
#  1   vendor_id                 2011 non-null   object
#  2   pickup_datetime           2011 non-null   datetime64[ns]
#  3   dropoff_datetime          2011 non-null   datetime64[ns]
#  4   pickup_longitude          2011 non-null   float64
#  5   pickup_latitude           2011 non-null   float64
#  6   dropoff_longitude         2011 non-null   float64
#  7   dropoff_latitude          2011 non-null   float64
#  8   store_and_fwd_flag        2011 non-null   object
#  9   trip_duration             2011 non-null   int64
#  10  dist_meters               2011 non-null   int64
#  11  wait_sec                  2011 non-null   int64
#  12  log_trip_duration         2011 non-null   float64
#  13  trip_duration_in_minutes  2011 non-null   float64
#  14  diff_datetime_minutes     2011 non-null   float64
#  15  pickup_month              2011 non-null   int64
#  16  pickup_year               2011 non-null   int64
#  17  pickup_day                2011 non-null   int64
#  18  pickup_hour               2011 non-null   int64
#  19  pickup_minute             2011 non-null   int64
#  20  pickup_day_of_week        2011 non-null   int64
#  21  log_dist_meters           2011 non-null   float64
#  22  dist_kilometers           2011 non-null   float64
#  23  cluster_pickup_ref3       2011 non-null   int32
#  24  cluster_pickup            2011 non-null   int32
#  25  cluster_dropoff           2011 non-null   int32
# dtypes: datetime64[ns](2), float64(9), int32(3), int64(10), object(2)
# memory usage: 465.2+ KB

# %%
correlation_matrix = uio.corr()
print(correlation_matrix['trip_duration'])
# Out:
# id                          0.008831
# pickup_longitude            0.082403
# pickup_latitude             0.127188
# dropoff_longitude           0.074405
# dropoff_latitude            0.106540
# trip_duration               1.000000
# dist_meters                 0.634449
# wait_sec                   -0.030354
# log_trip_duration           0.787982
# trip_duration_in_minutes    1.000000
# diff_datetime_minutes       0.313254
# pickup_month                0.004506
# pickup_year                 0.067830
# pickup_day                  0.039965
# pickup_hour                -0.071266
# pickup_minute               0.051755
# pickup_day_of_week         -0.012163
# log_dist_meters             0.540118
# dist_kilometers             0.634449
# cluster_pickup_ref3         0.102883
# cluster_pickup              0.028780
# cluster_dropoff            -0.032308
# Name: trip_duration, dtype: float64

# %%
sns.regplot(x=uio["trip_duration_in_minutes"], y=uio["dist_kilometers"])

# %%
df_uio = uio[['trip_duration','dist_meters']]
x = df_uio.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled)

df.columns = [list(df_uio.columns)]
print(df)
# Out:
#      trip_duration dist_meters
# 0         0.195851    0.594328
# 1         0.107746    0.353387
# 2         0.008714    0.015302
# 3         0.026003    0.121966
# 4         0.042185    0.116982
# ...            ...         ...
# 2006      0.018949    0.064896
# 2007      0.215214    0.195833
# 2008      0.604564    0.734287
# 2009      0.429184    0.566067
# 2010      0.724343    0.787121
#
# [2011 rows x 2 columns]

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#               trip_duration dist_meters
# trip_duration      1.000000    0.634449
# dist_meters        0.634449    1.000000

# %% [markdown]
# # **Split Data**

# %%
#uio_fix = uio[['trip_duration_in_minutes', 'dist_kilometers','pickup_hour']]
uio_fix = uio[['trip_duration_in_minutes', 'dist_kilometers','pickup_hour','pickup_month','pickup_year','pickup_latitude','pickup_longitude']]

# %%
uio_fix
# Out:
#       trip_duration_in_minutes  dist_kilometers  pickup_hour  pickup_month  \
# 0                    23.650000           11.935            1             9
# 1                    13.033333            7.101            3             9
# 3                     1.100000            0.318            4             9
# 7                     3.183333            2.458           10             9
# 8                     5.133333            2.358           10             9
# ...                        ...              ...          ...           ...
# 3053                  2.333333            1.313            4            10
# 3054                 25.983333            3.940            4            10
# 3055                 72.900000           14.743            6            10
# 3056                 51.766667           11.368            9            10
# 3061                 87.333333           15.803            7            10
#
#       pickup_year  pickup_latitude  pickup_longitude
# 0            2016         4.622699        -74.170353
# 1            2016         4.604075        -74.123542
# 3            2016         4.641949        -74.163398
# 7            2016         4.736697        -74.049168
# 8            2016         4.718333        -74.049272
# ...           ...              ...               ...
# 3053         2016         4.591986        -74.161670
# 3054         2016         4.578133        -74.156281
# 3055         2016         4.637313        -74.154898
# 3056         2016         4.631299        -74.072112
# 3061         2016         4.752078        -74.050934
#
# [2011 rows x 7 columns]

# %%
train_dataset = uio_fix.sample(frac=0.8, random_state=0)
test_dataset = uio_fix.drop(train_dataset.index)

# %%
sns.pairplot(train_dataset, diag_kind='kde')

# %%
train_dataset.describe().transpose()
# Out:
#                            count         mean        std          min  \
# trip_duration_in_minutes  1609.0    23.015786  22.909538     0.050000
# dist_kilometers           1609.0     5.439548   4.873559     0.011000
# pickup_hour               1609.0     6.674332   3.036608     1.000000
# pickup_month              1609.0     7.252952   3.264848     1.000000
# pickup_year               1609.0  2016.384711   0.486678  2016.000000
# pickup_latitude           1609.0     4.674357   0.060338     4.404473
# pickup_longitude          1609.0   -74.092529   0.041880   -74.452713
#
#                                   25%          50%          75%          max
# trip_duration_in_minutes     6.116667    16.900000    31.966667   120.550000
# dist_kilometers              1.280000     4.248000     8.316000    20.016000
# pickup_hour                  4.000000     7.000000     9.000000    12.000000
# pickup_month                 5.000000     7.000000    10.000000    12.000000
# pickup_year               2016.000000  2016.000000  2017.000000  2017.000000
# pickup_latitude              4.628135     4.687737     4.714473     5.029401
# pickup_longitude           -74.123773   -74.086499   -74.056637   -73.947104

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('trip_duration_in_minutes')
test_labels = test_features.pop('trip_duration_in_minutes')

# %%
train_dataset.describe().transpose()[['mean', 'std']]
# Out:
#                                  mean        std
# trip_duration_in_minutes    23.015786  22.909538
# dist_kilometers              5.439548   4.873559
# pickup_hour                  6.674332   3.036608
# pickup_month                 7.252952   3.264848
# pickup_year               2016.384711   0.486678
# pickup_latitude              4.674357   0.060338
# pickup_longitude           -74.092529   0.041880

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(np.array(train_features))
print(normalizer.mean.numpy())
# Out:
# [[   5.439548     6.6743317    7.2529526 2016.3851       4.674357
#    -74.09253  ]]

# %%
first = np.array(train_features[:1])

with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())
# Out:
# First example: [[   0.04    4.      3.   2017.      4.63  -74.18]]
#
# Normalized: [[-1.11 -0.88 -1.3   1.26 -0.69 -2.11]]

# %% [markdown]
# # **Linear Regression**

# %%
linear_model = tf.keras.Sequential([
    normalizer,
    layers.Dense(units=1)
])

linear_model.predict(train_features[:10])

linear_model.layers[1].kernel
# Out:
# <tf.Variable 'dense/kernel:0' shape=(2, 1) dtype=float32, numpy=
# array([[ 0.16585732],
#        [-0.10925746]], dtype=float32)>

# %%
linear_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# %%time
history = linear_model.fit(
    train_features,
    train_labels,
    epochs=100,
    #verbose=0,
    validation_split = 0.2)
# Out:
# Epoch 1/100
# 41/41 [==============================] - 1s 6ms/step - loss: 21.6752 - val_loss: 17.6558
# Epoch 2/100
# 41/41 [==============================] - 0s 2ms/step - loss: 17.9317 - val_loss: 13.9957
# Epoch 3/100
# 41/41 [==============================] - 0s 2ms/step - loss: 14.4658 - val_loss: 11.0876
# Epoch 4/100
# 41/41 [==============================] - 0s 3ms/step - loss: 12.1836 - val_loss: 9.3933
# Epoch 5/100
# 41/41 [==============================] - 0s 2ms/step - loss: 11.0505 - val_loss: 8.6239
# Epoch 6/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.5993 - val_loss: 8.3469
# Epoch 7/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4722 - val_loss: 8.2542
# Epoch 8/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4364 - val_loss: 8.2585
# Epoch 9/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4315 - val_loss: 8.2359
# Epoch 10/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4207 - val_loss: 8.2373
# Epoch 11/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4322 - val_loss: 8.2357
# Epoch 12/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4252 - val_loss: 8.2506
# Epoch 13/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4277 - val_loss: 8.2435
# Epoch 14/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4233 - val_loss: 8.2616
# Epoch 15/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4351 - val_loss: 8.2483
# Epoch 16/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4262 - val_loss: 8.2379
# Epoch 17/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4318 - val_loss: 8.2520
# Epoch 18/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4311 - val_loss: 8.2396
# Epoch 19/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4242 - val_loss: 8.2509
# Epoch 20/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4356 - val_loss: 8.2376
# Epoch 21/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4238 - val_loss: 8.2740
# Epoch 22/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4271 - val_loss: 8.2334
# Epoch 23/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4259 - val_loss: 8.2352
# Epoch 24/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4236 - val_loss: 8.2442
# Epoch 25/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4359 - val_loss: 8.2483
# Epoch 26/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4354 - val_loss: 8.2611
# Epoch 27/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4268 - val_loss: 8.2556
# Epoch 28/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4208 - val_loss: 8.2381
# Epoch 29/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4240 - val_loss: 8.2419
# Epoch 30/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4322 - val_loss: 8.2324
# Epoch 31/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4286 - val_loss: 8.2403
# Epoch 32/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4258 - val_loss: 8.2483
# Epoch 33/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4439 - val_loss: 8.2649
# Epoch 34/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4310 - val_loss: 8.2337
# Epoch 35/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4307 - val_loss: 8.2408
# Epoch 36/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4292 - val_loss: 8.2518
# Epoch 37/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4249 - val_loss: 8.2297
# Epoch 38/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4220 - val_loss: 8.2419
# Epoch 39/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4236 - val_loss: 8.2541
# Epoch 40/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4414 - val_loss: 8.2336
# Epoch 41/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4302 - val_loss: 8.2345
# Epoch 42/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4279 - val_loss: 8.2465
# Epoch 43/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4325 - val_loss: 8.2505
# Epoch 44/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4179 - val_loss: 8.2658
# Epoch 45/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4531 - val_loss: 8.2553
# Epoch 46/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4352 - val_loss: 8.2455
# Epoch 47/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4223 - val_loss: 8.2339
# Epoch 48/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4364 - val_loss: 8.2365
# Epoch 49/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4262 - val_loss: 8.2355
# Epoch 50/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4284 - val_loss: 8.2267
# Epoch 51/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4256 - val_loss: 8.2636
# Epoch 52/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4265 - val_loss: 8.2360
# Epoch 53/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4314 - val_loss: 8.2285
# Epoch 54/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4293 - val_loss: 8.2684
# Epoch 55/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4292 - val_loss: 8.2390
# Epoch 56/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4327 - val_loss: 8.2545
# Epoch 57/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4468 - val_loss: 8.2345
# Epoch 58/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4236 - val_loss: 8.2380
# Epoch 59/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4266 - val_loss: 8.2403
# Epoch 60/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4352 - val_loss: 8.2384
# Epoch 61/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4364 - val_loss: 8.2378
# Epoch 62/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4314 - val_loss: 8.2709
# Epoch 63/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4270 - val_loss: 8.2353
# Epoch 64/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4313 - val_loss: 8.2536
# Epoch 65/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4331 - val_loss: 8.2318
# Epoch 66/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4331 - val_loss: 8.2403
# Epoch 67/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4203 - val_loss: 8.2522
# Epoch 68/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4369 - val_loss: 8.2355
# Epoch 69/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4364 - val_loss: 8.2356
# Epoch 70/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4340 - val_loss: 8.2532
# Epoch 71/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4271 - val_loss: 8.2527
# Epoch 72/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4333 - val_loss: 8.2318
# Epoch 73/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4375 - val_loss: 8.2463
# Epoch 74/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4339 - val_loss: 8.2413
# Epoch 75/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4266 - val_loss: 8.2413
# Epoch 76/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4329 - val_loss: 8.2379
# Epoch 77/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4228 - val_loss: 8.2428
# Epoch 78/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4323 - val_loss: 8.2409
# Epoch 79/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4263 - val_loss: 8.2522
# Epoch 80/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4347 - val_loss: 8.2631
# Epoch 81/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4453 - val_loss: 8.2586
# Epoch 82/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4287 - val_loss: 8.2947
# Epoch 83/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4407 - val_loss: 8.2460
# Epoch 84/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4322 - val_loss: 8.2590
# Epoch 85/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4328 - val_loss: 8.2366
# Epoch 86/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4277 - val_loss: 8.2427
# Epoch 87/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4299 - val_loss: 8.2311
# Epoch 88/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4319 - val_loss: 8.2552
# Epoch 89/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4255 - val_loss: 8.2336
# Epoch 90/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4271 - val_loss: 8.2322
# Epoch 91/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4270 - val_loss: 8.2427
# Epoch 92/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4319 - val_loss: 8.2514
# Epoch 93/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4342 - val_loss: 8.2435
# Epoch 94/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4338 - val_loss: 8.2321
# Epoch 95/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4377 - val_loss: 8.2337
# Epoch 96/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4259 - val_loss: 8.2396
# Epoch 97/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4298 - val_loss: 8.2590
# Epoch 98/100
# 41/41 [==============================] - 0s 3ms/step - loss: 10.4282 - val_loss: 8.2402
# Epoch 99/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4276 - val_loss: 8.2492
# Epoch 100/100
# 41/41 [==============================] - 0s 2ms/step - loss: 10.4415 - val_loss: 8.2597
# CPU times: user 11.7 s, sys: 764 ms, total: 12.4 s
# Wall time: 21 s

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 10])
  plt.xlabel('Epoch')
  plt.ylabel('Error [trip_duration_in_minutes]')
  plt.legend()
  plt.grid(True)

# %%
plot_loss(history)

# %% [markdown]
# # **Regression**

# %%
def build_and_compile_model(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(100, activation='relu'),
      layers.Dense(10, activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_2 (Normalizat  (None, 6)                13
#  ion)
#
#  dense_4 (Dense)             (None, 100)               700
#
#  dense_5 (Dense)             (None, 10)                1010
#
#  dense_6 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1,734
# Trainable params: 1,721
# Non-trainable params: 13
# _________________________________________________________________

# %%
# %%time
history = dnn_model.fit(
    train_features,
    train_labels,
    batch_size = 100,
    validation_split=0.2,
    #verbose=0, 
    epochs=500)
# Out:
# Epoch 1/500
# 13/13 [==============================] - 1s 14ms/step - loss: 23.2014 - val_loss: 20.7982
# Epoch 2/500
# 13/13 [==============================] - 0s 6ms/step - loss: 22.5896 - val_loss: 20.1788
# Epoch 3/500
# 13/13 [==============================] - 0s 5ms/step - loss: 21.8896 - val_loss: 19.4854
# Epoch 4/500
# 13/13 [==============================] - 0s 6ms/step - loss: 21.0482 - val_loss: 18.6851
# Epoch 5/500
# 13/13 [==============================] - 0s 5ms/step - loss: 20.0391 - val_loss: 17.6822
# Epoch 6/500
# 13/13 [==============================] - 0s 5ms/step - loss: 18.8604 - val_loss: 16.4574
# Epoch 7/500
# 13/13 [==============================] - 0s 4ms/step - loss: 17.5169 - val_loss: 15.0187
# Epoch 8/500
# 13/13 [==============================] - 0s 6ms/step - loss: 16.0225 - val_loss: 13.6752
# Epoch 9/500
# 13/13 [==============================] - 0s 6ms/step - loss: 14.7202 - val_loss: 12.6156
# Epoch 10/500
# 13/13 [==============================] - 0s 4ms/step - loss: 13.6644 - val_loss: 11.8698
# Epoch 11/500
# 13/13 [==============================] - 0s 5ms/step - loss: 12.9630 - val_loss: 11.3078
# Epoch 12/500
# 13/13 [==============================] - 0s 6ms/step - loss: 12.4967 - val_loss: 10.7855
# Epoch 13/500
# 13/13 [==============================] - 0s 5ms/step - loss: 12.0754 - val_loss: 10.3227
# Epoch 14/500
# 13/13 [==============================] - 0s 5ms/step - loss: 11.7368 - val_loss: 9.9898
# Epoch 15/500
# 13/13 [==============================] - 0s 5ms/step - loss: 11.5154 - val_loss: 9.7369
# Epoch 16/500
# 13/13 [==============================] - 0s 4ms/step - loss: 11.3137 - val_loss: 9.5523
# Epoch 17/500
# 13/13 [==============================] - 0s 7ms/step - loss: 11.2038 - val_loss: 9.3713
# Epoch 18/500
# 13/13 [==============================] - 0s 5ms/step - loss: 11.0966 - val_loss: 9.2609
# Epoch 19/500
# 13/13 [==============================] - 0s 5ms/step - loss: 11.0097 - val_loss: 9.1758
# Epoch 20/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.9387 - val_loss: 9.1122
# Epoch 21/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.8876 - val_loss: 9.0337
# Epoch 22/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.8459 - val_loss: 8.9852
# Epoch 23/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.8139 - val_loss: 8.9210
# Epoch 24/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.7807 - val_loss: 8.9143
# Epoch 25/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.7523 - val_loss: 8.8533
# Epoch 26/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.7233 - val_loss: 8.8195
# Epoch 27/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.6970 - val_loss: 8.8054
# Epoch 28/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.6734 - val_loss: 8.7734
# Epoch 29/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.6512 - val_loss: 8.7522
# Epoch 30/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.6300 - val_loss: 8.7032
# Epoch 31/500
# 13/13 [==============================] - 0s 7ms/step - loss: 10.6107 - val_loss: 8.6732
# Epoch 32/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.5877 - val_loss: 8.6666
# Epoch 33/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.5735 - val_loss: 8.6290
# Epoch 34/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.5651 - val_loss: 8.5942
# Epoch 35/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.5371 - val_loss: 8.5917
# Epoch 36/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.5229 - val_loss: 8.5716
# Epoch 37/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.5249 - val_loss: 8.5538
# Epoch 38/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.4942 - val_loss: 8.5216
# Epoch 39/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.4855 - val_loss: 8.5013
# Epoch 40/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.4657 - val_loss: 8.4737
# Epoch 41/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.4534 - val_loss: 8.4704
# Epoch 42/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.4448 - val_loss: 8.4598
# Epoch 43/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.4288 - val_loss: 8.4392
# Epoch 44/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.4305 - val_loss: 8.4140
# Epoch 45/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.4151 - val_loss: 8.4368
# Epoch 46/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.3955 - val_loss: 8.3895
# Epoch 47/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.3779 - val_loss: 8.3929
# Epoch 48/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.3710 - val_loss: 8.3773
# Epoch 49/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.3643 - val_loss: 8.3397
# Epoch 50/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.3517 - val_loss: 8.3549
# Epoch 51/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.3490 - val_loss: 8.3563
# Epoch 52/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.3302 - val_loss: 8.3265
# Epoch 53/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.3315 - val_loss: 8.3060
# Epoch 54/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.3150 - val_loss: 8.3241
# Epoch 55/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.3104 - val_loss: 8.3060
# Epoch 56/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.3030 - val_loss: 8.2944
# Epoch 57/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.2899 - val_loss: 8.2995
# Epoch 58/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.2925 - val_loss: 8.3005
# Epoch 59/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.2827 - val_loss: 8.2770
# Epoch 60/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.2759 - val_loss: 8.2587
# Epoch 61/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.2706 - val_loss: 8.2483
# Epoch 62/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.2610 - val_loss: 8.2456
# Epoch 63/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.2565 - val_loss: 8.2412
# Epoch 64/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.2448 - val_loss: 8.2466
# Epoch 65/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.2422 - val_loss: 8.2319
# Epoch 66/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.2412 - val_loss: 8.2380
# Epoch 67/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.2335 - val_loss: 8.2291
# Epoch 68/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.2345 - val_loss: 8.2075
# Epoch 69/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.2203 - val_loss: 8.2163
# Epoch 70/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.2115 - val_loss: 8.2075
# Epoch 71/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.2122 - val_loss: 8.2029
# Epoch 72/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.2035 - val_loss: 8.1776
# Epoch 73/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.2228 - val_loss: 8.1970
# Epoch 74/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.1959 - val_loss: 8.1624
# Epoch 75/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.2030 - val_loss: 8.1905
# Epoch 76/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.1856 - val_loss: 8.1746
# Epoch 77/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.1864 - val_loss: 8.1612
# Epoch 78/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.1809 - val_loss: 8.1796
# Epoch 79/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.1752 - val_loss: 8.1705
# Epoch 80/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.1778 - val_loss: 8.1308
# Epoch 81/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.1636 - val_loss: 8.1621
# Epoch 82/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.1697 - val_loss: 8.1477
# Epoch 83/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.1586 - val_loss: 8.1453
# Epoch 84/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.1590 - val_loss: 8.1307
# Epoch 85/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.1539 - val_loss: 8.1500
# Epoch 86/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.1473 - val_loss: 8.1399
# Epoch 87/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.1435 - val_loss: 8.1091
# Epoch 88/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.1427 - val_loss: 8.1528
# Epoch 89/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.1432 - val_loss: 8.1225
# Epoch 90/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.1352 - val_loss: 8.1333
# Epoch 91/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.1398 - val_loss: 8.1240
# Epoch 92/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.1421 - val_loss: 8.0987
# Epoch 93/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.1293 - val_loss: 8.1157
# Epoch 94/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.1235 - val_loss: 8.1285
# Epoch 95/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.1216 - val_loss: 8.0979
# Epoch 96/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.1145 - val_loss: 8.1130
# Epoch 97/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.1090 - val_loss: 8.1106
# Epoch 98/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.1145 - val_loss: 8.1030
# Epoch 99/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.1060 - val_loss: 8.1098
# Epoch 100/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.1069 - val_loss: 8.1197
# Epoch 101/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.1084 - val_loss: 8.0802
# Epoch 102/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.1060 - val_loss: 8.1066
# Epoch 103/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0989 - val_loss: 8.1029
# Epoch 104/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.1044 - val_loss: 8.0775
# Epoch 105/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.0949 - val_loss: 8.1126
# Epoch 106/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0906 - val_loss: 8.0918
# Epoch 107/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0931 - val_loss: 8.0995
# Epoch 108/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.0912 - val_loss: 8.0819
# Epoch 109/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0804 - val_loss: 8.0950
# Epoch 110/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0809 - val_loss: 8.1019
# Epoch 111/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0730 - val_loss: 8.0774
# Epoch 112/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0772 - val_loss: 8.0716
# Epoch 113/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0685 - val_loss: 8.0854
# Epoch 114/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.0762 - val_loss: 8.0862
# Epoch 115/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0720 - val_loss: 8.0794
# Epoch 116/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0700 - val_loss: 8.0968
# Epoch 117/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0748 - val_loss: 8.0885
# Epoch 118/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0751 - val_loss: 8.0779
# Epoch 119/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0837 - val_loss: 8.0937
# Epoch 120/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0735 - val_loss: 8.0776
# Epoch 121/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0604 - val_loss: 8.0988
# Epoch 122/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0612 - val_loss: 8.0534
# Epoch 123/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0609 - val_loss: 8.0797
# Epoch 124/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0563 - val_loss: 8.0840
# Epoch 125/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0546 - val_loss: 8.0769
# Epoch 126/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0543 - val_loss: 8.0667
# Epoch 127/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0527 - val_loss: 8.0673
# Epoch 128/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.0496 - val_loss: 8.0644
# Epoch 129/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.0426 - val_loss: 8.0776
# Epoch 130/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0475 - val_loss: 8.0559
# Epoch 131/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0438 - val_loss: 8.0757
# Epoch 132/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.0427 - val_loss: 8.0694
# Epoch 133/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0470 - val_loss: 8.0598
# Epoch 134/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0344 - val_loss: 8.0875
# Epoch 135/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0357 - val_loss: 8.0602
# Epoch 136/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0312 - val_loss: 8.0730
# Epoch 137/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0346 - val_loss: 8.0679
# Epoch 138/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0420 - val_loss: 8.0689
# Epoch 139/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0287 - val_loss: 8.0667
# Epoch 140/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.0313 - val_loss: 8.0645
# Epoch 141/500
# 13/13 [==============================] - 0s 7ms/step - loss: 10.0284 - val_loss: 8.0649
# Epoch 142/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0226 - val_loss: 8.0705
# Epoch 143/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0313 - val_loss: 8.0693
# Epoch 144/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0236 - val_loss: 8.0512
# Epoch 145/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0140 - val_loss: 8.0760
# Epoch 146/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0162 - val_loss: 8.0736
# Epoch 147/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0162 - val_loss: 8.0617
# Epoch 148/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0167 - val_loss: 8.0763
# Epoch 149/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0146 - val_loss: 8.0675
# Epoch 150/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0112 - val_loss: 8.0481
# Epoch 151/500
# 13/13 [==============================] - 0s 7ms/step - loss: 10.0153 - val_loss: 8.0908
# Epoch 152/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0091 - val_loss: 8.0491
# Epoch 153/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0070 - val_loss: 8.0640
# Epoch 154/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0119 - val_loss: 8.0730
# Epoch 155/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0193 - val_loss: 8.0668
# Epoch 156/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0036 - val_loss: 8.0630
# Epoch 157/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0113 - val_loss: 8.0677
# Epoch 158/500
# 13/13 [==============================] - 0s 4ms/step - loss: 10.0097 - val_loss: 8.0953
# Epoch 159/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0066 - val_loss: 8.0701
# Epoch 160/500
# 13/13 [==============================] - 0s 6ms/step - loss: 10.0098 - val_loss: 8.0681
# Epoch 161/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9941 - val_loss: 8.0748
# Epoch 162/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.9952 - val_loss: 8.0656
# Epoch 163/500
# 13/13 [==============================] - 0s 5ms/step - loss: 10.0041 - val_loss: 8.0763
# Epoch 164/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.9856 - val_loss: 8.0585
# Epoch 165/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9925 - val_loss: 8.0765
# Epoch 166/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9990 - val_loss: 8.0665
# Epoch 167/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9886 - val_loss: 8.0860
# Epoch 168/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9902 - val_loss: 8.0659
# Epoch 169/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9957 - val_loss: 8.0643
# Epoch 170/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9919 - val_loss: 8.0521
# Epoch 171/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9833 - val_loss: 8.0943
# Epoch 172/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9787 - val_loss: 8.0523
# Epoch 173/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.9869 - val_loss: 8.0949
# Epoch 174/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9823 - val_loss: 8.0727
# Epoch 175/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9716 - val_loss: 8.0594
# Epoch 176/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9785 - val_loss: 8.0564
# Epoch 177/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.9656 - val_loss: 8.0717
# Epoch 178/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9645 - val_loss: 8.0619
# Epoch 179/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9719 - val_loss: 8.0856
# Epoch 180/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9667 - val_loss: 8.0540
# Epoch 181/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9686 - val_loss: 8.0821
# Epoch 182/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.9607 - val_loss: 8.0512
# Epoch 183/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9646 - val_loss: 8.0720
# Epoch 184/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9705 - val_loss: 8.0918
# Epoch 185/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.9678 - val_loss: 8.0571
# Epoch 186/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.9703 - val_loss: 8.0917
# Epoch 187/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9532 - val_loss: 8.0591
# Epoch 188/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9516 - val_loss: 8.0550
# Epoch 189/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.9483 - val_loss: 8.0667
# Epoch 190/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9562 - val_loss: 8.0631
# Epoch 191/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9642 - val_loss: 8.0644
# Epoch 192/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9486 - val_loss: 8.0678
# Epoch 193/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9443 - val_loss: 8.0712
# Epoch 194/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9676 - val_loss: 8.0439
# Epoch 195/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9559 - val_loss: 8.0717
# Epoch 196/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9462 - val_loss: 8.0691
# Epoch 197/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9403 - val_loss: 8.0864
# Epoch 198/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9411 - val_loss: 8.0560
# Epoch 199/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9390 - val_loss: 8.0603
# Epoch 200/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9355 - val_loss: 8.0656
# Epoch 201/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9299 - val_loss: 8.0487
# Epoch 202/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.9468 - val_loss: 8.0645
# Epoch 203/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.9464 - val_loss: 8.0532
# Epoch 204/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9341 - val_loss: 8.0878
# Epoch 205/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9527 - val_loss: 8.0815
# Epoch 206/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9339 - val_loss: 8.0675
# Epoch 207/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9272 - val_loss: 8.0619
# Epoch 208/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9248 - val_loss: 8.0679
# Epoch 209/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.9185 - val_loss: 8.0403
# Epoch 210/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9219 - val_loss: 8.0578
# Epoch 211/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9380 - val_loss: 8.0593
# Epoch 212/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.9234 - val_loss: 8.0847
# Epoch 213/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9246 - val_loss: 8.0327
# Epoch 214/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9151 - val_loss: 8.0871
# Epoch 215/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9109 - val_loss: 8.0660
# Epoch 216/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9167 - val_loss: 8.0539
# Epoch 217/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9139 - val_loss: 8.0632
# Epoch 218/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9401 - val_loss: 8.0715
# Epoch 219/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9147 - val_loss: 8.0602
# Epoch 220/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9031 - val_loss: 8.0532
# Epoch 221/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.9101 - val_loss: 8.0537
# Epoch 222/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9147 - val_loss: 8.0459
# Epoch 223/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.9108 - val_loss: 8.0727
# Epoch 224/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9021 - val_loss: 8.0571
# Epoch 225/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9027 - val_loss: 8.0610
# Epoch 226/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8924 - val_loss: 8.0626
# Epoch 227/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8963 - val_loss: 8.0604
# Epoch 228/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8913 - val_loss: 8.0528
# Epoch 229/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.9088 - val_loss: 8.0656
# Epoch 230/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8918 - val_loss: 8.0351
# Epoch 231/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.9066 - val_loss: 8.0438
# Epoch 232/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8973 - val_loss: 8.0562
# Epoch 233/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.9091 - val_loss: 8.0625
# Epoch 234/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8864 - val_loss: 8.0557
# Epoch 235/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8830 - val_loss: 8.0581
# Epoch 236/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8898 - val_loss: 8.0514
# Epoch 237/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8807 - val_loss: 8.0663
# Epoch 238/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8875 - val_loss: 8.0584
# Epoch 239/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8880 - val_loss: 8.0671
# Epoch 240/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8804 - val_loss: 8.0536
# Epoch 241/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8889 - val_loss: 8.0493
# Epoch 242/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8745 - val_loss: 8.0568
# Epoch 243/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.8675 - val_loss: 8.0513
# Epoch 244/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8659 - val_loss: 8.0634
# Epoch 245/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8690 - val_loss: 8.0701
# Epoch 246/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8665 - val_loss: 8.0543
# Epoch 247/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8640 - val_loss: 8.0454
# Epoch 248/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8588 - val_loss: 8.0451
# Epoch 249/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8706 - val_loss: 8.0574
# Epoch 250/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8727 - val_loss: 8.0427
# Epoch 251/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8682 - val_loss: 8.0577
# Epoch 252/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8795 - val_loss: 8.0709
# Epoch 253/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8639 - val_loss: 8.0571
# Epoch 254/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8605 - val_loss: 8.0758
# Epoch 255/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8544 - val_loss: 8.0599
# Epoch 256/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8471 - val_loss: 8.0485
# Epoch 257/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.8579 - val_loss: 8.0401
# Epoch 258/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8581 - val_loss: 8.0758
# Epoch 259/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8469 - val_loss: 8.0642
# Epoch 260/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8584 - val_loss: 8.0586
# Epoch 261/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8409 - val_loss: 8.0657
# Epoch 262/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8420 - val_loss: 8.0693
# Epoch 263/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8434 - val_loss: 8.0538
# Epoch 264/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8382 - val_loss: 8.0601
# Epoch 265/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8435 - val_loss: 8.0764
# Epoch 266/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8442 - val_loss: 8.0512
# Epoch 267/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8356 - val_loss: 8.0758
# Epoch 268/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8293 - val_loss: 8.0629
# Epoch 269/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.8351 - val_loss: 8.0629
# Epoch 270/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8431 - val_loss: 8.0677
# Epoch 271/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8301 - val_loss: 8.0471
# Epoch 272/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8297 - val_loss: 8.0671
# Epoch 273/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8246 - val_loss: 8.0785
# Epoch 274/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8387 - val_loss: 8.0561
# Epoch 275/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8376 - val_loss: 8.0911
# Epoch 276/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8280 - val_loss: 8.0792
# Epoch 277/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8291 - val_loss: 8.0554
# Epoch 278/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8265 - val_loss: 8.0797
# Epoch 279/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8189 - val_loss: 8.0772
# Epoch 280/500
# 13/13 [==============================] - 0s 9ms/step - loss: 9.8137 - val_loss: 8.0614
# Epoch 281/500
# 13/13 [==============================] - 0s 22ms/step - loss: 9.8211 - val_loss: 8.0815
# Epoch 282/500
# 13/13 [==============================] - 0s 16ms/step - loss: 9.8251 - val_loss: 8.0650
# Epoch 283/500
# 13/13 [==============================] - 0s 16ms/step - loss: 9.8080 - val_loss: 8.0875
# Epoch 284/500
# 13/13 [==============================] - 0s 12ms/step - loss: 9.8110 - val_loss: 8.0624
# Epoch 285/500
# 13/13 [==============================] - 0s 11ms/step - loss: 9.8177 - val_loss: 8.1124
# Epoch 286/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8155 - val_loss: 8.0453
# Epoch 287/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8072 - val_loss: 8.0772
# Epoch 288/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8069 - val_loss: 8.0744
# Epoch 289/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8033 - val_loss: 8.0781
# Epoch 290/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8088 - val_loss: 8.0687
# Epoch 291/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7981 - val_loss: 8.0855
# Epoch 292/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7988 - val_loss: 8.0615
# Epoch 293/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8116 - val_loss: 8.0768
# Epoch 294/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8061 - val_loss: 8.0904
# Epoch 295/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8086 - val_loss: 8.0803
# Epoch 296/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8004 - val_loss: 8.0718
# Epoch 297/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7973 - val_loss: 8.0772
# Epoch 298/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8079 - val_loss: 8.0892
# Epoch 299/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7988 - val_loss: 8.0681
# Epoch 300/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7933 - val_loss: 8.0912
# Epoch 301/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7906 - val_loss: 8.0809
# Epoch 302/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8090 - val_loss: 8.1041
# Epoch 303/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7976 - val_loss: 8.0814
# Epoch 304/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7929 - val_loss: 8.0666
# Epoch 305/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7839 - val_loss: 8.0820
# Epoch 306/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.8072 - val_loss: 8.1210
# Epoch 307/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8031 - val_loss: 8.0829
# Epoch 308/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8062 - val_loss: 8.0904
# Epoch 309/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7908 - val_loss: 8.0839
# Epoch 310/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7994 - val_loss: 8.0850
# Epoch 311/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7825 - val_loss: 8.1068
# Epoch 312/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7730 - val_loss: 8.0706
# Epoch 313/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7910 - val_loss: 8.0948
# Epoch 314/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7840 - val_loss: 8.0837
# Epoch 315/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7768 - val_loss: 8.0821
# Epoch 316/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7737 - val_loss: 8.0711
# Epoch 317/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7692 - val_loss: 8.1067
# Epoch 318/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7754 - val_loss: 8.0858
# Epoch 319/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7600 - val_loss: 8.0983
# Epoch 320/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7682 - val_loss: 8.0762
# Epoch 321/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7687 - val_loss: 8.0925
# Epoch 322/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7674 - val_loss: 8.0774
# Epoch 323/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7638 - val_loss: 8.0921
# Epoch 324/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7551 - val_loss: 8.0866
# Epoch 325/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7568 - val_loss: 8.1108
# Epoch 326/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7598 - val_loss: 8.1042
# Epoch 327/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7879 - val_loss: 8.0800
# Epoch 328/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7669 - val_loss: 8.1305
# Epoch 329/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7724 - val_loss: 8.0767
# Epoch 330/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7707 - val_loss: 8.1049
# Epoch 331/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7672 - val_loss: 8.0930
# Epoch 332/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7600 - val_loss: 8.1049
# Epoch 333/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7627 - val_loss: 8.1167
# Epoch 334/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7526 - val_loss: 8.1063
# Epoch 335/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7480 - val_loss: 8.0957
# Epoch 336/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7505 - val_loss: 8.1049
# Epoch 337/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7407 - val_loss: 8.0972
# Epoch 338/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7465 - val_loss: 8.0966
# Epoch 339/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7523 - val_loss: 8.0904
# Epoch 340/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7475 - val_loss: 8.1017
# Epoch 341/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7368 - val_loss: 8.1119
# Epoch 342/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7402 - val_loss: 8.1199
# Epoch 343/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7632 - val_loss: 8.1135
# Epoch 344/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7324 - val_loss: 8.0930
# Epoch 345/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7319 - val_loss: 8.0880
# Epoch 346/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7404 - val_loss: 8.1101
# Epoch 347/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7498 - val_loss: 8.1337
# Epoch 348/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7328 - val_loss: 8.1120
# Epoch 349/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7315 - val_loss: 8.1007
# Epoch 350/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7533 - val_loss: 8.1033
# Epoch 351/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7229 - val_loss: 8.1484
# Epoch 352/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7195 - val_loss: 8.1174
# Epoch 353/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7278 - val_loss: 8.1343
# Epoch 354/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7376 - val_loss: 8.1083
# Epoch 355/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7303 - val_loss: 8.0948
# Epoch 356/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7213 - val_loss: 8.1134
# Epoch 357/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7150 - val_loss: 8.1020
# Epoch 358/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7139 - val_loss: 8.1142
# Epoch 359/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7309 - val_loss: 8.1071
# Epoch 360/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7138 - val_loss: 8.1180
# Epoch 361/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7157 - val_loss: 8.0983
# Epoch 362/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7099 - val_loss: 8.1296
# Epoch 363/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7072 - val_loss: 8.1100
# Epoch 364/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7099 - val_loss: 8.1253
# Epoch 365/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7092 - val_loss: 8.1395
# Epoch 366/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7192 - val_loss: 8.1334
# Epoch 367/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7136 - val_loss: 8.1410
# Epoch 368/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7088 - val_loss: 8.1203
# Epoch 369/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7041 - val_loss: 8.1265
# Epoch 370/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7094 - val_loss: 8.1269
# Epoch 371/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.7050 - val_loss: 8.1241
# Epoch 372/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7022 - val_loss: 8.1156
# Epoch 373/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7021 - val_loss: 8.1320
# Epoch 374/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6975 - val_loss: 8.1350
# Epoch 375/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6984 - val_loss: 8.1532
# Epoch 376/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6891 - val_loss: 8.1278
# Epoch 377/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6847 - val_loss: 8.1292
# Epoch 378/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6831 - val_loss: 8.1192
# Epoch 379/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.6923 - val_loss: 8.1499
# Epoch 380/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6899 - val_loss: 8.1337
# Epoch 381/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6843 - val_loss: 8.1355
# Epoch 382/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6872 - val_loss: 8.1373
# Epoch 383/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6820 - val_loss: 8.1364
# Epoch 384/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7019 - val_loss: 8.1561
# Epoch 385/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6997 - val_loss: 8.1463
# Epoch 386/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.6813 - val_loss: 8.1236
# Epoch 387/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6873 - val_loss: 8.1558
# Epoch 388/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6848 - val_loss: 8.1501
# Epoch 389/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6794 - val_loss: 8.1496
# Epoch 390/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6815 - val_loss: 8.1384
# Epoch 391/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6842 - val_loss: 8.1295
# Epoch 392/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6764 - val_loss: 8.1531
# Epoch 393/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6701 - val_loss: 8.1313
# Epoch 394/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.6812 - val_loss: 8.1436
# Epoch 395/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6785 - val_loss: 8.1292
# Epoch 396/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6784 - val_loss: 8.1832
# Epoch 397/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6855 - val_loss: 8.1463
# Epoch 398/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6853 - val_loss: 8.1668
# Epoch 399/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.6845 - val_loss: 8.1416
# Epoch 400/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.6706 - val_loss: 8.1461
# Epoch 401/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.6862 - val_loss: 8.1430
# Epoch 402/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6841 - val_loss: 8.1862
# Epoch 403/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.6721 - val_loss: 8.1376
# Epoch 404/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6674 - val_loss: 8.1822
# Epoch 405/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6709 - val_loss: 8.1524
# Epoch 406/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.6702 - val_loss: 8.1474
# Epoch 407/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6621 - val_loss: 8.1730
# Epoch 408/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6612 - val_loss: 8.1681
# Epoch 409/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.6570 - val_loss: 8.1480
# Epoch 410/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6624 - val_loss: 8.1554
# Epoch 411/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6562 - val_loss: 8.1366
# Epoch 412/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6568 - val_loss: 8.1666
# Epoch 413/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6663 - val_loss: 8.1602
# Epoch 414/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6728 - val_loss: 8.1838
# Epoch 415/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.6550 - val_loss: 8.1537
# Epoch 416/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6509 - val_loss: 8.1463
# Epoch 417/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6650 - val_loss: 8.1879
# Epoch 418/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6574 - val_loss: 8.1507
# Epoch 419/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.6513 - val_loss: 8.1541
# Epoch 420/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6399 - val_loss: 8.1676
# Epoch 421/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6580 - val_loss: 8.1593
# Epoch 422/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6531 - val_loss: 8.1792
# Epoch 423/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6433 - val_loss: 8.1972
# Epoch 424/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6473 - val_loss: 8.1832
# Epoch 425/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6558 - val_loss: 8.1838
# Epoch 426/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6393 - val_loss: 8.1990
# Epoch 427/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6381 - val_loss: 8.1949
# Epoch 428/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6302 - val_loss: 8.1710
# Epoch 429/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6333 - val_loss: 8.1651
# Epoch 430/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6268 - val_loss: 8.1643
# Epoch 431/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6573 - val_loss: 8.1539
# Epoch 432/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6582 - val_loss: 8.1819
# Epoch 433/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6562 - val_loss: 8.1687
# Epoch 434/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6394 - val_loss: 8.2147
# Epoch 435/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6394 - val_loss: 8.1578
# Epoch 436/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6294 - val_loss: 8.2002
# Epoch 437/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6298 - val_loss: 8.1672
# Epoch 438/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6224 - val_loss: 8.1923
# Epoch 439/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6354 - val_loss: 8.1984
# Epoch 440/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6259 - val_loss: 8.1714
# Epoch 441/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6192 - val_loss: 8.1859
# Epoch 442/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6244 - val_loss: 8.2055
# Epoch 443/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6236 - val_loss: 8.1682
# Epoch 444/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.6157 - val_loss: 8.1901
# Epoch 445/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6449 - val_loss: 8.2067
# Epoch 446/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6288 - val_loss: 8.1833
# Epoch 447/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6226 - val_loss: 8.2089
# Epoch 448/500
# 13/13 [==============================] - 0s 4ms/step - loss: 9.6104 - val_loss: 8.1750
# Epoch 449/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6241 - val_loss: 8.1975
# Epoch 450/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6180 - val_loss: 8.2065
# Epoch 451/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6184 - val_loss: 8.1861
# Epoch 452/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6061 - val_loss: 8.1859
# Epoch 453/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6265 - val_loss: 8.2167
# Epoch 454/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6259 - val_loss: 8.1898
# Epoch 455/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6179 - val_loss: 8.1898
# Epoch 456/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6029 - val_loss: 8.1749
# Epoch 457/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6180 - val_loss: 8.2238
# Epoch 458/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5941 - val_loss: 8.1974
# Epoch 459/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6100 - val_loss: 8.1889
# Epoch 460/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6054 - val_loss: 8.1923
# Epoch 461/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.5935 - val_loss: 8.2196
# Epoch 462/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6053 - val_loss: 8.1982
# Epoch 463/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6104 - val_loss: 8.2035
# Epoch 464/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6060 - val_loss: 8.1856
# Epoch 465/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6092 - val_loss: 8.1988
# Epoch 466/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6088 - val_loss: 8.2062
# Epoch 467/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.5952 - val_loss: 8.2222
# Epoch 468/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5991 - val_loss: 8.1894
# Epoch 469/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6034 - val_loss: 8.1973
# Epoch 470/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.5969 - val_loss: 8.1848
# Epoch 471/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5919 - val_loss: 8.2240
# Epoch 472/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.6080 - val_loss: 8.1911
# Epoch 473/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5867 - val_loss: 8.2045
# Epoch 474/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5904 - val_loss: 8.2039
# Epoch 475/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5979 - val_loss: 8.2227
# Epoch 476/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5943 - val_loss: 8.2598
# Epoch 477/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5934 - val_loss: 8.1797
# Epoch 478/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.5866 - val_loss: 8.2144
# Epoch 479/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.6082 - val_loss: 8.2125
# Epoch 480/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5703 - val_loss: 8.1820
# Epoch 481/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.5782 - val_loss: 8.2081
# Epoch 482/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.5737 - val_loss: 8.2133
# Epoch 483/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.5891 - val_loss: 8.2191
# Epoch 484/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.5730 - val_loss: 8.2029
# Epoch 485/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.6070 - val_loss: 8.2181
# Epoch 486/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5845 - val_loss: 8.1910
# Epoch 487/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.5943 - val_loss: 8.2523
# Epoch 488/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5746 - val_loss: 8.1960
# Epoch 489/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.5781 - val_loss: 8.2103
# Epoch 490/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5818 - val_loss: 8.2094
# Epoch 491/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.5787 - val_loss: 8.2279
# Epoch 492/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.5730 - val_loss: 8.2072
# Epoch 493/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.5673 - val_loss: 8.2166
# Epoch 494/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.5644 - val_loss: 8.2011
# Epoch 495/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5846 - val_loss: 8.2097
# Epoch 496/500
# 13/13 [==============================] - 0s 7ms/step - loss: 9.5636 - val_loss: 8.2170
# Epoch 497/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5576 - val_loss: 8.2177
# Epoch 498/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.5689 - val_loss: 8.2174
# Epoch 499/500
# 13/13 [==============================] - 0s 5ms/step - loss: 9.5608 - val_loss: 8.2281
# Epoch 500/500
# 13/13 [==============================] - 0s 6ms/step - loss: 9.5747 - val_loss: 8.2236
# CPU times: user 36.2 s, sys: 2.15 s, total: 38.3 s
# Wall time: 41.4 s

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 25])
  plt.xlabel('Epoch')
  plt.ylabel('Error [trip_duration_in_minutes]')
  plt.legend()
  plt.grid(True)

# %%
plot_loss(history)

# %%
test_results = {}

# %%
test_results['dnn_model'] = dnn_model.evaluate(test_features, test_labels, verbose=0)

# %%
pd.DataFrame(test_results, index=['Mean absolute error [trip_duration]']).T
# Out:
#            Mean absolute error [trip_duration]
# dnn_model                             9.030483

# %% [markdown]
# # **Make Prediction**

# %%
test_predictions = dnn_model.predict(test_features).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [trip_duration]')
plt.ylabel('Predictions [trip_duration]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [trip_duration]')
_ = plt.ylabel('Count')

# %%
plt.figure()
plt.plot(test_predictions, label='predicted')
plt.plot(test_labels, label='actual')
plt.ylabel('output y')
plt.legend()
plt.show()

# %%
print(test_predictions[0:5])
# Out:
# [16.655327  13.724868   2.3598433  4.6560454  6.0527816]

# %%
print(test_labels[0:5])
# Out:
# 18    16.333333
# 34    18.950000
# 37     1.966667
# 38     4.866667
# 44    20.633333
# Name: trip_duration_in_minutes, dtype: float64

# %%
print(test_features[0:5])
# Out:
#     dist_kilometers  pickup_hour  pickup_month  pickup_year  pickup_latitude  \
# 18            4.766            7             9         2016         4.595093
# 34            3.681           11             9         2016         4.578534
# 37            0.558           12             9         2016         4.597882
# 38            0.663            1             9         2016         4.716862
# 44            1.564            4             9         2016         4.704668
#
#     pickup_longitude
# 18        -74.073965
# 34        -74.128194
# 37        -74.130444
# 38        -74.082277
# 44        -74.071009

# %%
uio.loc[[37,44]]
# Out:
#     id vendor_id     pickup_datetime    dropoff_datetime  pickup_longitude  \
# 37  38   BogotÃ¡ 2016-09-21 12:47:13 2016-09-21 12:49:10        -74.130444
# 44  45   BogotÃ¡ 2016-09-21 04:45:13 2016-09-21 05:05:50        -74.071009
#
#     pickup_latitude  dropoff_longitude  dropoff_latitude store_and_fwd_flag  \
# 37         4.597882         -74.126482          4.595579                  N
# 44         4.704668         -74.075151          4.693989                  N
#
#     trip_duration  ...  trip_duration_in_minutes  diff_datetime_minutes  \
# 37            118  ...                  1.966667               1.950000
# 44           1238  ...                 20.633333              20.616667
#
#     pickup_month  pickup_year  pickup_day  pickup_hour  pickup_minute  \
# 37             9         2016          21           12             47
# 44             9         2016          21            4             45
#
#     pickup_day_of_week  log_dist_meters  dist_kilometers
# 37                   2         6.326149            0.558
# 44                   2         7.355641            1.564
#
# [2 rows x 23 columns]
